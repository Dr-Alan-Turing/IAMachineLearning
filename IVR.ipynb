# %%
# Import packages
from __future__ import division, print_function # Imports from __future__ since we're running Python 2
import os
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
y = [20, 45, 55, 80, 55, 45, 20, 45, 55, 80, 55, 45, 20, 45, 55, 80, 55, 45, 20, 45, 55, 80]
x = []
for i in range(len(y)):
    x.append(i/5)
plt.plot(x,y)
plt.ylabel("colour intensity (%)", fontsize=14)
plt.xlabel("time (s)", fontsize=14)
plt.ylim(0, 100)
plt.show()

# %%
y = [100, 100, 100, 100, 50, 45, 40, 35, 30, 25, 20, 15, 10]
x = range(len(y))
plt.plot(x,y)
plt.ylabel("sonar reading (distance in cm)", fontsize=14)
plt.xlabel("time (s)", fontsize=14)
plt.ylim(0, 99)
plt.show()
